# %% [markdown]
# <a href="https://colab.research.google.com/github/superbunny38/2021MachineLearning/blob/main/seminar/ImplementationofDecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Criterion of best splitting point

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Gini impurity

# %%
def gini_impurity(labels):
  #When the set is empty, it is also pure(impurity = 0)
  if labels.size == 0:
    return 0
  
  #Count
